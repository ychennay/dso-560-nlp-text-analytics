# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Basic-File-Operations" data-toc-modified-id="Basic-File-Operations-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Basic File Operations</a></span><ul class="toc-item"><li><span><a href="#Read-the-first-line-from-the-dataset" data-toc-modified-id="Read-the-first-line-from-the-dataset-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Read the first line from the dataset</a></span></li><li><span><a href="#Reset-the-pointer-of-the-stream-back-to-the-start-of-the-text-file" data-toc-modified-id="Reset-the-pointer-of-the-stream-back-to-the-start-of-the-text-file-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Reset the pointer of the stream back to the start of the text file</a></span></li><li><span><a href="#Read-in-the-Entire-File-as-a-List-of-Strings" data-toc-modified-id="Read-in-the-Entire-File-as-a-List-of-Strings-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Read in the Entire File as a List of Strings</a></span></li><li><span><a href="#Read-in-the-Entire-File-as-One-String" data-toc-modified-id="Read-in-the-Entire-File-as-One-String-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Read in the Entire File as One String</a></span></li></ul></li><li><span><a href="#Regex" data-toc-modified-id="Regex-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Regex</a></span><ul class="toc-item"><li><span><a href="#Parse-Out-All-Dollar-Amount-References-In-the-Reviews" data-toc-modified-id="Parse-Out-All-Dollar-Amount-References-In-the-Reviews-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Parse Out All Dollar Amount References In the Reviews</a></span></li></ul></li><li><span><a href="#Encodings" data-toc-modified-id="Encodings-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Encodings</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Download-the-example_utf8_encoding.csv-and-load-it-into-memory" data-toc-modified-id="Download-the-example_utf8_encoding.csv-and-load-it-into-memory-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Download the <code>example_utf8_encoding.csv</code> and load it into memory</a></span></li></ul></li><li><span><a href="#Using-a-File-IO-Stream" data-toc-modified-id="Using-a-File-IO-Stream-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Using a File IO Stream</a></span></li><li><span><a href="#Using-Pandas-Dataframe" data-toc-modified-id="Using-Pandas-Dataframe-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Using Pandas Dataframe</a></span></li></ul></li><li><span><a href="#Load-in-example_default_mac_encoding.csv" data-toc-modified-id="Load-in-example_default_mac_encoding.csv-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Load in <code>example_default_mac_encoding.csv</code></a></span></li><li><span><a href="#Using-a-File-IO-Stream" data-toc-modified-id="Using-a-File-IO-Stream-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Using a File IO Stream</a></span></li><li><span><a href="#Using-Pandas-DataFrame" data-toc-modified-id="Using-Pandas-DataFrame-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Using Pandas DataFrame</a></span></li><li><span><a href="#Explain-the-Diffference-in-Output-Between-latin1-and-utf8" data-toc-modified-id="Explain-the-Diffference-in-Output-Between-latin1-and-utf8-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Explain the Diffference in Output Between <code>latin1</code> and <code>utf8</code></a></span></li><li><span><a href="#True-or-False-Statements" data-toc-modified-id="True-or-False-Statements-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>True or False Statements</a></span><ul class="toc-item"><li><span><a href="#ASCII-is-an-encoding-scheme." data-toc-modified-id="ASCII-is-an-encoding-scheme.-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>ASCII is an encoding scheme.</a></span></li><li><span><a href="#Unicode-is-an-encoding-scheme." data-toc-modified-id="Unicode-is-an-encoding-scheme.-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Unicode is an encoding scheme.</a></span></li><li><span><a href="#UTF-16-can-represent-twice-as-many-characters-as-UTF-8" data-toc-modified-id="UTF-16-can-represent-twice-as-many-characters-as-UTF-8-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>UTF-16 can represent twice as many characters as UTF-8</a></span></li><li><span><a href="#UTF-8-is-more-memory-efficient-than-UTF-16-/-UTF-32." data-toc-modified-id="UTF-8-is-more-memory-efficient-than-UTF-16-/-UTF-32.-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>UTF-8 is more memory efficient than UTF-16 / UTF-32.</a></span></li><li><span><a href="#The-character-🤗-can-be-represented-in-latin1" data-toc-modified-id="The-character-🤗-can-be-represented-in-latin1-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>The character 🤗 can be represented in <code>latin1</code></a></span></li></ul></li><li><span><a href="#Unicode-Code-Points" data-toc-modified-id="Unicode-Code-Points-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Unicode Code Points</a></span></li></ul></li></ul></div>

# %% [markdown]
# This is a notebook for students who
# * joined the class after Week 1 and need to make up Week 1 in-class credit
# * have a valid reason why they were unable to attend Week 1 communicated to the instructor **prior to class** and want to make up credit
# * students who want additional practice

# %% [markdown]
# # Basic File Operations
# Load in the `good_amazon_toy_reviews.txt` (located in our **AWS DSO 560 S3 bucket**) dataset using `open()`.

# %%
filename = "good_amazon_toy_reviews.txt"
bucket_name = "dso-560-nlp-text-analytics"

import boto3
s3client = boto3.client('s3')
s3client.download_file(bucket_name, # bucket name
                       filename, # name of file you want to download
                       filename) # filename you want to save it as

# %%
file = open(filename)

# %% [markdown]
# ## Read the first line from the dataset

# %% [markdown]
# ## Reset the pointer of the stream back to the start of the text file

# %% [markdown]
# ## Read in the Entire File as a List of Strings

# %% [markdown]
# ## Read in the Entire File as One String

# %% [markdown]
# # Regex

# %% [markdown]
# ## Parse Out All Dollar Amount References In the Reviews
# Note that people will refer to dollar amounts differently. Some people will say "X dollars". Others will use **$2.99**. First take a look at how people are referring to dollar amounts, and then write a regex that properly finds all references to dollar amounts.

# %% [markdown]
# # Encodings

# %% [markdown]
# #### Download the `example_utf8_encoding.csv` and load it into memory

# %% [markdown]
# ### Using a File IO Stream

# %% [markdown]
# ### Using Pandas Dataframe

# %% [markdown]
# ## Load in `example_default_mac_encoding.csv`

# %% [markdown]
# ## Using a File IO Stream

# %% [markdown]
# ## Using Pandas DataFrame

# %% [markdown]
# ## Explain the Diffference in Output Between `latin1` and `utf8`
# In particular, why are certain characters rendered properly but other ones mangled?

# %% [markdown]
# ## True or False Statements
# If **False**, explain why it is false.

# %% [markdown]
# ### ASCII is an encoding scheme.

# %% [markdown]
# ### Unicode is an encoding scheme.

# %% [markdown]
# ### UTF-16 can represent twice as many characters as UTF-8

# %% [markdown]
# ### UTF-8 is more memory efficient than UTF-16 / UTF-32.

# %% [markdown]
# ### The character 🤗 can be represented in `latin1`

# %% [markdown]
# ## Unicode Code Points
#
# 1. Is it possible to convert the term `Cuántas` into bytes using **`ASCII`** encoding? If not, why not? If so, show your work (ie. show the multiplication steps - `0 x 64 + 1 x 32 + 0 x 16 ...`.

# %% [markdown]
# 2. Is it possible to convert the term `Cuántas` into bytes using **`latin1`** encoding? If not, why not? If so, show your work (ie. show the multiplication steps - `0 x 64 + 1 x 32 + 0 x 16 ...`.
